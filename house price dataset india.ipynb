# %%
import pandas as pd

# %%
path ='/content/drive/MyDrive/archive.zip'

# %%
# read the file
df=pd.read_csv(path)

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
# univariate analysis

# %%
plt.hist(df['lot area'])
# Out:
# (array([1.4313e+04, 1.7600e+02, 9.2000e+01, 1.9000e+01, 1.4000e+01,
#         2.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 3.0000e+00]),
#  array([5.200000e+02, 1.078898e+05, 2.152596e+05, 3.226294e+05,
#         4.299992e+05, 5.373690e+05, 6.447388e+05, 7.521086e+05,
#         8.594784e+05, 9.668482e+05, 1.074218e+06]),
#  <BarContainer object of 10 artists>)

# %%
#Bivariate Analysis

# %%
plt.bar(df['living area'],df['lot area'])
plt.xlabel('livingarea')
plt.ylabel('lotarea')
plt.title('living vs lot area')
# Out:
# Text(0.5, 1.0, 'living vs lot area')

# %%
plt.scatter(df['living area'],df['lot area'])

# %%
#multi variate analysis

# %%
d={"living area":[3650,2920,2910,3310,2710,1556,1680,1070,1030],"lot area":[9050,4000,9480,42998,4500,20000,7000,6120,6621]," number of floors":[2.0,1.5,1.5,2.0,1.5,1.0,1.5,1.0,1.0] }
data = pd.DataFrame(d)
data
# Out:
#    living area  lot area   number of floors
# 0         3650      9050                2.0
# 1         2920      4000                1.5
# 2         2910      9480                1.5
# 3         3310     42998                2.0
# 4         2710      4500                1.5
# 5         1556     20000                1.0
# 6         1680      7000                1.5
# 7         1070      6120                1.0
# 8         1030      6621                1.0

# %%
# perform descriptive statistics on the data set

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...
